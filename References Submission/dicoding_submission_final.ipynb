# %%
# install kaggle package
# !pip install -q kaggle

# %%
# upload kaggle.json
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-908100a6-9fcb-44c4-9f02-5f412d527e4d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-908100a6-9fcb-44c4-9f02-5f412d527e4d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"nurimammasri","key":"c1155f6163293daec115b33a4ba22c8b"}'}

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# !ls ~/.kaggle
# Out:
# kaggle.json

# %%
# !kaggle datasets download -d madisona/translated-animals10
# Out:
# Downloading translated-animals10.zip to /content
#  98% 577M/586M [00:10<00:00, 54.8MB/s]
# 100% 586M/586M [00:10<00:00, 57.9MB/s]

# %%
# unzip
# !mkdir animals
# !unzip -qq translated-animals10.zip -d animals
# !ls animals
# Out:
# animals10

# %%
# !ls animals/animals10/raw-img/
# Out:
# butterfly  cat	chicken  cow  dog  elephant  horse  sheep  spider  squirrel

# %%
import os

animals = os.path.join('/content/animals/animals10/raw-img/')

print(os.listdir(animals))
# Out:
# ['sheep', 'horse', 'cat', 'squirrel', 'spider', 'butterfly', 'elephant', 'cow', 'dog', 'chicken']

# %%
import shutil

ignore_animals = ['squirrel', 'cat', 'butterfly', 'sheep', 'cow', 'horse']

for x in ignore_animals:
  path = os.path.join(animals, x)
  shutil.rmtree(path)

# %%
list_animals = os.listdir(animals)
print(list_animals)
# Out:
# ['spider', 'elephant', 'dog', 'chicken']

# %%
from PIL import Image
total = 0

for x in list_animals:
  dir = os.path.join(animals, x)
  y = len(os.listdir(dir))
  print(x+':', y)
  total = total + y
  
  img_name = os.listdir(dir)
  for z in range(4):
    img_path = os.path.join(dir, img_name[z])
    img = Image.open(img_path)
    print('-',img.size)
  print('---------------')

print('\nTotal :', total)
# Out:
# spider: 4821
# - (271, 300)
# - (202, 300)
# - (259, 300)
# - (300, 200)
# ---------------
# elephant: 1446
# - (640, 360)
# - (200, 300)
# - (640, 360)
# - (300, 183)
# ---------------
# dog: 4863
# - (254, 300)
# - (300, 225)
# - (203, 300)
# - (300, 157)
# ---------------
# chicken: 3098
# - (300, 259)
# - (250, 187)
# - (300, 225)
# - (300, 225)
# ---------------
#
# Total : 14228

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots(2, 2, figsize=(15,15))
fig.suptitle("Randomly displays images.", fontsize=24)
animals_sorted = sorted(list_animals)
animals_id = 0
for i in range(2):
  for j in range(2):
    try:
      animals_selected = animals_sorted[animals_id] 
      animals_id += 1
    except:
      break
    if animals_selected == '.TEMP':
        continue
    animals_selected_images = os.listdir(os.path.join(animals, animals_selected))
    animals_selected_random = np.random.choice(animals_selected_images)
    img = plt.imread(os.path.join(animals, animals_selected, animals_selected_random))
    ax[i][j].imshow(img)
    ax[i][j].set_title(animals_selected, pad=10, fontsize=22)
    
plt.setp(ax, xticks=[],yticks=[])
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
 
train_datagen = ImageDataGenerator(
    rotation_range=40,
    width_shift_range=0.2,
    height_shift_range=0.2,
    rescale=1/255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest',
    validation_split=0.2   
)

# %%
batch_size = 256

data_train = train_datagen.flow_from_directory(
    animals,
    target_size=(150, 150),
    batch_size=batch_size,
    class_mode='categorical',
    subset='training')

data_val = train_datagen.flow_from_directory(
    animals, 
    target_size=(150, 150),
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation')
# Out:
# Found 11384 images belonging to 4 classes.
# Found 2844 images belonging to 4 classes.

# %%
import tensorflow as tf
# from tensorflow.keras import applications, optimizers

tf.device('/device:GPU:0')

model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),

    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dropout(0.5), 
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(4, activation='softmax')
])

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics = ['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 148, 148, 64)      1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 74, 74, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 72, 72, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 34, 34, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 17, 17, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 15, 15, 128)       147584
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 7, 7, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 6272)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 6272)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               3211776
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 2052
# =================================================================
# Total params: 3,473,988
# Trainable params: 3,473,988
# Non-trainable params: 0
# _________________________________________________________________

# %%
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('accuracy')>0.92 and logs.get('val_accuracy')>0.92):
      print("\nAccuracy above 92%, finish training!")
      self.model.stop_training = True

callbacks = myCallback()

# %%
data_train.samples // batch_size
# Out:
# 44

# %%
data_val.samples // batch_size
# Out:
# 11

# %%
history = model.fit(data_train, 
                    epochs = 40, 
                    steps_per_epoch = data_train.samples // batch_size,
                    validation_data = data_val, 
                    validation_steps = data_val.samples // batch_size,
                    verbose = 1,
                    callbacks = [callbacks])
# Out:
# Epoch 1/40
# 44/44 [==============================] - 119s 2s/step - loss: 1.3717 - accuracy: 0.3377 - val_loss: 1.2660 - val_accuracy: 0.3864
# Epoch 2/40
# 44/44 [==============================] - 83s 2s/step - loss: 1.2151 - accuracy: 0.4478 - val_loss: 1.1417 - val_accuracy: 0.5362
# Epoch 3/40
# 44/44 [==============================] - 83s 2s/step - loss: 1.0601 - accuracy: 0.5597 - val_loss: 1.0166 - val_accuracy: 0.5696
# Epoch 4/40
# 44/44 [==============================] - 82s 2s/step - loss: 0.9440 - accuracy: 0.6230 - val_loss: 0.8771 - val_accuracy: 0.6768
# Epoch 5/40
# 44/44 [==============================] - 83s 2s/step - loss: 0.8505 - accuracy: 0.6744 - val_loss: 0.7607 - val_accuracy: 0.7060
# Epoch 6/40
# 44/44 [==============================] - 83s 2s/step - loss: 0.7529 - accuracy: 0.7128 - val_loss: 0.8376 - val_accuracy: 0.6715
# Epoch 7/40
# 44/44 [==============================] - 83s 2s/step - loss: 0.7559 - accuracy: 0.7162 - val_loss: 0.6793 - val_accuracy: 0.7287
# Epoch 8/40
# 44/44 [==============================] - 82s 2s/step - loss: 0.6527 - accuracy: 0.7570 - val_loss: 0.6888 - val_accuracy: 0.7365
# Epoch 9/40
# 44/44 [==============================] - 84s 2s/step - loss: 0.6246 - accuracy: 0.7610 - val_loss: 0.5748 - val_accuracy: 0.7741
# Epoch 10/40
# 44/44 [==============================] - 82s 2s/step - loss: 0.5719 - accuracy: 0.7834 - val_loss: 0.5558 - val_accuracy: 0.7915
# Epoch 11/40
# 44/44 [==============================] - 82s 2s/step - loss: 0.5365 - accuracy: 0.8005 - val_loss: 0.5184 - val_accuracy: 0.8068
# Epoch 12/40
# 44/44 [==============================] - 82s 2s/step - loss: 0.5739 - accuracy: 0.7835 - val_loss: 0.5984 - val_accuracy: 0.7724
# Epoch 13/40
# 44/44 [==============================] - 82s 2s/step - loss: 0.5314 - accuracy: 0.8074 - val_loss: 0.4902 - val_accuracy: 0.8196
# Epoch 14/40
# 44/44 [==============================] - 82s 2s/step - loss: 0.4876 - accuracy: 0.8153 - val_loss: 0.4450 - val_accuracy: 0.8384
# Epoch 15/40
# 44/44 [==============================] - 82s 2s/step - loss: 0.4581 - accuracy: 0.8307 - val_loss: 0.4489 - val_accuracy: 0.8345
# Epoch 16/40
# 44/44 [==============================] - 83s 2s/step - loss: 0.4503 - accuracy: 0.8334 - val_loss: 0.4698 - val_accuracy: 0.8317
# Epoch 17/40
# 44/44 [==============================] - 82s 2s/step - loss: 0.4567 - accuracy: 0.8384 - val_loss: 0.4467 - val_accuracy: 0.8359
# Epoch 18/40
# 44/44 [==============================] - 83s 2s/step - loss: 0.4433 - accuracy: 0.8348 - val_loss: 0.4432 - val_accuracy: 0.8327
# Epoch 19/40
# 44/44 [==============================] - 83s 2s/step - loss: 0.4382 - accuracy: 0.8454 - val_loss: 0.4108 - val_accuracy: 0.8523
# Epoch 20/40
# 44/44 [==============================] - 82s 2s/step - loss: 0.4318 - accuracy: 0.8432 - val_loss: 0.3834 - val_accuracy: 0.8675
# Epoch 21/40
# 44/44 [==============================] - 83s 2s/step - loss: 0.3905 - accuracy: 0.8550 - val_loss: 0.4134 - val_accuracy: 0.8516
# Epoch 22/40
# 44/44 [==============================] - 83s 2s/step - loss: 0.3882 - accuracy: 0.8541 - val_loss: 0.3907 - val_accuracy: 0.8612
# Epoch 23/40
# 44/44 [==============================] - 82s 2s/step - loss: 0.3738 - accuracy: 0.8632 - val_loss: 0.4235 - val_accuracy: 0.8555
# Epoch 24/40
# 44/44 [==============================] - 84s 2s/step - loss: 0.3745 - accuracy: 0.8642 - val_loss: 0.3788 - val_accuracy: 0.8544
# Epoch 25/40
# 44/44 [==============================] - 84s 2s/step - loss: 0.3811 - accuracy: 0.8563 - val_loss: 0.4007 - val_accuracy: 0.8480
# Epoch 26/40
# 44/44 [==============================] - 85s 2s/step - loss: 0.3523 - accuracy: 0.8731 - val_loss: 0.3894 - val_accuracy: 0.8619
# Epoch 27/40
# 44/44 [==============================] - 83s 2s/step - loss: 0.3439 - accuracy: 0.8754 - val_loss: 0.5010 - val_accuracy: 0.8274
# Epoch 28/40
# 44/44 [==============================] - 83s 2s/step - loss: 0.3868 - accuracy: 0.8604 - val_loss: 0.3672 - val_accuracy: 0.8640
# Epoch 29/40
# 44/44 [==============================] - 82s 2s/step - loss: 0.3658 - accuracy: 0.8632 - val_loss: 0.4031 - val_accuracy: 0.8565
# Epoch 30/40
# 44/44 [==============================] - 84s 2s/step - loss: 0.3511 - accuracy: 0.8747 - val_loss: 0.3151 - val_accuracy: 0.8857
# Epoch 31/40
# 44/44 [==============================] - 84s 2s/step - loss: 0.3359 - accuracy: 0.8821 - val_loss: 0.3393 - val_accuracy: 0.8782
# Epoch 32/40
# 44/44 [==============================] - 83s 2s/step - loss: 0.3259 - accuracy: 0.8782 - val_loss: 0.3463 - val_accuracy: 0.8714
# Epoch 33/40
# 44/44 [==============================] - 83s 2s/step - loss: 0.3343 - accuracy: 0.8777 - val_loss: 0.4067 - val_accuracy: 0.8484
# Epoch 34/40
# 44/44 [==============================] - 83s 2s/step - loss: 0.3377 - accuracy: 0.8743 - val_loss: 0.3171 - val_accuracy: 0.8878
# Epoch 35/40
# 44/44 [==============================] - 83s 2s/step - loss: 0.3266 - accuracy: 0.8793 - val_loss: 0.3120 - val_accuracy: 0.8963
# Epoch 36/40
# 44/44 [==============================] - 83s 2s/step - loss: 0.2978 - accuracy: 0.8935 - val_loss: 0.3453 - val_accuracy: 0.8754
# Epoch 37/40
# 44/44 [==============================] - 83s 2s/step - loss: 0.2999 - accuracy: 0.8936 - val_loss: 0.3275 - val_accuracy: 0.8832
# Epoch 38/40
# 44/44 [==============================] - 83s 2s/step - loss: 0.2861 - accuracy: 0.8938 - val_loss: 0.3128 - val_accuracy: 0.8924
# Epoch 39/40
# 44/44 [==============================] - 83s 2s/step - loss: 0.2853 - accuracy: 0.8949 - val_loss: 0.3380 - val_accuracy: 0.8796
# Epoch 40/40
# 44/44 [==============================] - 84s 2s/step - loss: 0.3112 - accuracy: 0.8883 - val_loss: 0.2740 - val_accuracy: 0.9041

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

with tf.io.gfile.GFile('model.tflite', 'wb') as f:
  f.write(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmpyez777so/assets

# %%
# !ls -la | grep 'model'
# Out:
# -rw-r--r-- 1 root root  13900412 Apr 12 01:24 model.tflite
